# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv(r"D:\New folder\beauty of kashmir\OneDrive\Desktop\New folder (2)\Car Sales.xlsx - car_data.csv")

# %%
df
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male          13500
# 1      C_CND_000002    1/2/2022           Gia    Male        1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male        1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male          13500
# 4      C_CND_000005    1/2/2022         Grace    Male        1465000
# ...             ...         ...           ...     ...            ...
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# ...

# %% [markdown]
# Count total rows and columns

# %%
df.shape
# Out:
# (23906, 16)

# %%
df.head(20)
# Out:
#           Car_id      Date Customer Name  Gender  Annual Income  \
# 0   C_CND_000001  1/2/2022     Geraldine    Male          13500
# 1   C_CND_000002  1/2/2022           Gia    Male        1480000
# 2   C_CND_000003  1/2/2022        Gianna    Male        1035000
# 3   C_CND_000004  1/2/2022       Giselle    Male          13500
# 4   C_CND_000005  1/2/2022         Grace    Male        1465000
# 5   C_CND_000006  1/2/2022     Guadalupe    Male         850000
# 6   C_CND_000007  1/2/2022        Hailey    Male        1600000
# 7   C_CND_000008  1/2/2022        Graham    Male          13500
# 8   C_CND_000009  1/2/2022         Naomi    Male         815000
# 9   C_CND_000010  1/2/2022       Grayson  Female          13500
# 10  C_CND_000011  1/2/2022       Gregory    Male          13500
# 11  C_CND_000012  1/2/2022        Amar'E    Male          13500
# 12  C_CND_000013  1/2/2022       Griffin    Male         885000
# 13  C_CND_000014  1/2/2022      Harrison    Male          13500
# ...

# %%
df['Company'].nunique()
# Out:
# 30

# %%
company_list = df['Company'].unique()
print(company_list)
# Out:
# ['Ford' 'Dodge' 'Cadillac' 'Toyota' 'Acura' 'Mitsubishi' 'Chevrolet'
#  'Nissan' 'Mercury' 'BMW' 'Chrysler' 'Subaru' 'Hyundai' 'Honda' 'Infiniti'
#  'Audi' 'Porsche' 'Volkswagen' 'Buick' 'Saturn' 'Mercedes-B' 'Jaguar'
#  'Volvo' 'Pontiac' 'Lincoln' 'Oldsmobile' 'Lexus' 'Plymouth' 'Saab' 'Jeep']

# %%
df.describe
# Out:
# <bound method NDFrame.describe of              Car_id        Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male          13500
# 1      C_CND_000002    1/2/2022           Gia    Male        1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male        1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male          13500
# 4      C_CND_000005    1/2/2022         Grace    Male        1465000
# ...             ...         ...           ...     ...            ...
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# ...

# %%
print(df.isnull().sum())
# Out:
# Car_id           0
# Date             0
# Customer Name    1
# Gender           0
# Annual Income    0
# Dealer_Name      0
# Company          0
# Model            0
# Engine           0
# Transmission     0
# Color            0
# Price ($)        0
# Dealer_No        0
# Body Style       0
# Phone            0
# Dealer_Region    0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of              Car_id        Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male          13500
# 1      C_CND_000002    1/2/2022           Gia    Male        1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male        1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male          13500
# 4      C_CND_000005    1/2/2022         Grace    Male        1465000
# ...             ...         ...           ...     ...            ...
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# ...

# %% [markdown]
# Total Customer Count Male and female

# %%
sns.countplot(x='Gender', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.boxplot(x='Gender', y='Annual Income', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Annual Income'>

# %%
df.groupby('Gender')['Annual Income'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
sns.scatterplot(x='Annual Income', y='Price ($)', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Annual Income', ylabel='Price ($)'>

# %%
company_customer_counts = df['Company'].value_counts().reset_index()
company_customer_counts.columns = ['Company', 'CustomerCount']

# %% [markdown]
# COUNT NUMBER OF CUSTOMERS PER COMPANY

# %%
sns.barplot(x='CustomerCount', y='Company', data=company_customer_counts)
# Out:
# <Axes: xlabel='CustomerCount', ylabel='Company'>

# %%
color_pref = df.groupby(['Gender', 'Color']).size().reset_index(name='Count')

# %%
Gendar Preferance over color

# %%
sns.barplot(x='Color', y='Count', hue='Gender', data=color_pref)
# Out:
# <Axes: xlabel='Color', ylabel='Count'>

# %%
df.head(50)
# Out:
#           Car_id      Date Customer Name  Gender  Annual Income  \
# 0   C_CND_000001  1/2/2022     Geraldine    Male          13500
# 1   C_CND_000002  1/2/2022           Gia    Male        1480000
# 2   C_CND_000003  1/2/2022        Gianna    Male        1035000
# 3   C_CND_000004  1/2/2022       Giselle    Male          13500
# 4   C_CND_000005  1/2/2022         Grace    Male        1465000
# 5   C_CND_000006  1/2/2022     Guadalupe    Male         850000
# 6   C_CND_000007  1/2/2022        Hailey    Male        1600000
# 7   C_CND_000008  1/2/2022        Graham    Male          13500
# 8   C_CND_000009  1/2/2022         Naomi    Male         815000
# 9   C_CND_000010  1/2/2022       Grayson  Female          13500
# 10  C_CND_000011  1/2/2022       Gregory    Male          13500
# 11  C_CND_000012  1/2/2022        Amar'E    Male          13500
# 12  C_CND_000013  1/2/2022       Griffin    Male         885000
# 13  C_CND_000014  1/2/2022      Harrison    Male          13500
# ...

# %%
Company_pref = df.groupby(['Company', 'Gender']).size().reset_index(name='Count')

# %%
# Plot using seaborn
sns.barplot(x='Company', y='Count', hue='Gender', data=Company_pref)
# Out:
# <Axes: xlabel='Company', ylabel='Count'>

# %% [markdown]
# TOP 20 MODEL SALE

# %%
model_counts = df['Model'].value_counts().reset_index()
model_counts.columns = ['Model', 'SalesCount']

# %%
top_20_models = model_counts.head(20)

# %%
# Plot using seaborn
sns.barplot(x='SalesCount', y='Model', data=top_20_models)
# Out:
# <Axes: xlabel='SalesCount', ylabel='Model'>

# %% [markdown]
# Body style preference by gender

# %%
sns.countplot(x='Body Style', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Body Style', ylabel='count'>

# %%
df['Engine'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Engine'>

# %% [markdown]
# Price Variation with Engine Type

# %%
sns.violinplot(x='Engine', y='Price ($)', data=df)
# Out:
# <Axes: xlabel='Engine', ylabel='Price ($)'>

# %% [markdown]
# Price vs Engine Type with Body Style

# %%
sns.scatterplot(x='Engine', y='Price ($)', hue='Body Style', data=df)
# Out:
# <Axes: xlabel='Engine', ylabel='Price ($)'>
